# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/watch?v=RkdFkhfMK2k

# %%
pip install rembg
# Out:
# Collecting rembg
#   Downloading rembg-2.0.25-py3-none-any.whl (12 kB)
# Collecting asyncer==0.0.1
#   Downloading asyncer-0.0.1-py3-none-any.whl (8.1 kB)
# Collecting scipy==1.7.3
#   Downloading scipy-1.7.3-cp310-cp310-win_amd64.whl (34.3 MB)
#      --------------------------------------- 34.3/34.3 MB 22.6 MB/s eta 0:00:00
# Collecting gdown==4.5.1
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting opencv-python-headless==4.6.0.66
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-win_amd64.whl (35.5 MB)
#      --------------------------------------- 35.5/35.5 MB 17.7 MB/s eta 0:00:00
# Collecting filetype==1.1.0
#   Downloading filetype-1.1.0-py2.py3-none-any.whl (17 kB)
# Collecting pymatting==1.1.8
#   Downloading PyMatting-1.1.8-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.7/47.7 kB 1.2 MB/s eta 0:00:00
# Collecting imagehash==4.2.1
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      ------------------------------------- 812.6/812.6 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting watchdog==2.1.9
#   Downloading watchdog-2.1.9-py3-none-win_amd64.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 2.2 MB/s eta 0:00:00
# Collecting onnxruntime==1.12.1
#   Downloading onnxruntime-1.12.1-cp310-cp310-win_amd64.whl (5.8 MB)
#      ---------------------------------------- 5.8/5.8 MB 26.5 MB/s eta 0:00:00
# Collecting numpy==1.21.6
#   Downloading numpy-1.21.6-cp310-cp310-win_amd64.whl (14.0 MB)
#      --------------------------------------- 14.0/14.0 MB 27.3 MB/s eta 0:00:00
# Collecting click==8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 2.8 MB/s eta 0:00:00
# Collecting pillow==9.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 23.2 MB/s eta 0:00:00
# Collecting scikit-image==0.19.3
#   Downloading scikit_image-0.19.3-cp310-cp310-win_amd64.whl (12.0 MB)
#      --------------------------------------- 12.0/12.0 MB 28.5 MB/s eta 0:00:00
# Collecting uvicorn==0.18.3
#   Downloading uvicorn-0.18.3-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.4/57.4 kB 1.5 MB/s eta 0:00:00
# Collecting python-multipart==0.0.5
#   Downloading python-multipart-0.0.5.tar.gz (32 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tqdm==4.64.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 2.2 MB/s eta 0:00:00
# Collecting fastapi==0.80.0
#   Downloading fastapi-0.80.0-py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.8/54.8 kB 1.4 MB/s eta 0:00:00
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp310-cp310-win_amd64.whl (555 kB)
#      ------------------------------------- 555.1/555.1 kB 11.6 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp310-cp310-win_amd64.whl (27 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.9/55.9 kB 1.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->rembg) (22.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.1-cp310-cp310-win_amd64.whl (33 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from asyncer==0.0.1->rembg) (3.6.2)
# Requirement already satisfied: colorama in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from click==8.1.3->rembg) (0.4.5)
# Collecting starlette==0.19.1
#   Downloading starlette-0.19.1-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.3/63.3 kB 1.7 MB/s eta 0:00:00
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Downloading pydantic-1.10.2-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from gdown==4.5.1->rembg) (1.16.0)
# Collecting filelock
#   Downloading filelock-3.8.0-py3-none-any.whl (10 kB)
# Collecting requests[socks]
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from gdown==4.5.1->rembg) (4.11.1)
# Collecting PyWavelets
#   Downloading PyWavelets-1.4.1-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 26.6 MB/s eta 0:00:00
# Collecting flatbuffers
#   Downloading flatbuffers-22.10.26-py2.py3-none-any.whl (26 kB)
# Collecting protobuf
#   Downloading protobuf-4.21.9-cp310-abi3-win_amd64.whl (525 kB)
#      ------------------------------------- 525.5/525.5 kB 11.0 MB/s eta 0:00:00
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 27.5 MB/s eta 0:00:00
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      -------------------------------------- 46.0/46.0 kB 253.7 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime==1.12.1->rembg) (21.3)
# Collecting numba!=0.49.0
#   Downloading numba-0.56.3-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 14.3 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      -------------------------------------- 210.3/210.3 kB 4.3 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.8.7-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 21.4 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.2-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 24.0 MB/s eta 0:00:00
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from anyio<4.0.0,>=3.4.0->asyncer==0.0.1->rembg) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from anyio<4.0.0,>=3.4.0->asyncer==0.0.1->rembg) (3.4)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp310-cp310-win_amd64.whl (23.2 MB)
#      --------------------------------------- 23.2/23.2 MB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from numba!=0.49.0->pymatting==1.1.8->rembg) (63.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from packaging->onnxruntime==1.12.1->rembg) (3.0.9)
# Collecting typing-extensions>=4.1.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jh\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown==4.5.1->rembg) (2.3.2.post1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 2.5 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      -------------------------------------- 161.1/161.1 kB 3.2 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.4/140.4 kB 2.8 MB/s eta 0:00:00
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ------------------------------------- 532.6/532.6 kB 11.4 MB/s eta 0:00:00
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: gdown
#   Building wheel for gdown (pyproject.toml): started
#   Building wheel for gdown (pyproject.toml): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=b1cbe548d5f63ece71096c0b55ec2e25312fe55fc76c6345310859db38e3e584
#   Stored in directory: c:\users\jh\appdata\local\pip\cache\wheels\73\b9\12\4bc74ed5fe80e24c009a13db76b5edf7fa550dc426094fd284
# Successfully built gdown
# Installing collected packages: pyreadline3, mpmath, flatbuffers, filetype, watchdog, urllib3, typing-extensions, tqdm, sympy, python-multipart, PySocks, protobuf, pillow, numpy, networkx, multidict, llvmlite, humanfriendly, h11, frozenlist, filelock, click, charset-normalizer, certifi, async-timeout, yarl, uvicorn, tifffile, starlette, scipy, requests, PyWavelets, pydantic, opencv-python-headless, numba, imageio, coloredlogs, asyncer, aiosignal, scikit-image, pymatting, onnxruntime, imagehash, fastapi, aiohttp, gdown, rembg
#   Running setup.py install for python-multipart: started
#   Running setup.py install for python-multipart: finished with status 'done'
#   Running setup.py install for imagehash: started
#   Running setup.py install for imagehash: finished with status 'done'
# Successfully installed PySocks-1.7.1 PyWavelets-1.4.1 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asyncer-0.0.1 certifi-2022.9.24 charset-normalizer-2.1.1 click-8.1.3 coloredlogs-15.0.1 fastapi-0.80.0 filelock-3.8.0 filetype-1.1.0 flatbuffers-22.10.26 frozenlist-1.3.1 gdown-4.5.1 h11-0.14.0 humanfriendly-10.0 imagehash-4.2.1 imageio-2.22.2 llvmlite-0.39.1 mpmath-1.2.1 multidict-6.0.2 networkx-2.8.7 numba-0.56.3 numpy-1.21.6 onnxruntime-1.12.1 opencv-python-headless-4.6.0.66 pillow-9.2.0 protobuf-4.21.9 pydantic-1.10.2 pymatting-1.1.8 pyreadline3-3.4.1 python-multipart-0.0.5 rembg-2.0.25 requests-2.28.1 scikit-image-0.19.3 scipy-1.7.3 starlette-0.19.1 sympy-1.11.1 tifffile-2022.10.10 tqdm-4.64.0 typing-extensions-4.4.0 urllib3-1.26.12 uvicorn-0.18.3 watchdog-2.1.9 yarl-1.8.1
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: python-multipart is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   DEPRECATION: imagehash is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
from rembg import remove
from PIL import Image

input_path = 'image.jpg'
output_path = 'image.png'
inp = Image.open(input_path)
output = remove(inp)
output.save(output_path)

#clcoding.com
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 6
#       4 input_path = 'image.jpg'
#       5 output_path = 'image.png'
# ----> 6 inp = Image.open(input_path)
#       7 output = remove(inp)
#       8 output.save(output_path)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3092, in open(fp, mode, formats)
#    3089     filename = fp
#    3091 if filename:
# -> 3092     fp = builtins.open(filename, "rb")
#    3093     exclusive_fp = True
#    3095 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image.jpg'
