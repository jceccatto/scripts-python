# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/watch?v=vZVVTJhU4cg&feature=youtu.be

# %%
pip install countryinfo
# Out:
# Collecting countryinfo
#   Downloading countryinfo-0.1.2-py3-none-any.whl (602 kB)
#      -------------------------------------- 602.2/602.2 kB 9.5 MB/s eta 0:00:00
# Installing collected packages: countryinfo
# Successfully installed countryinfo-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from countryinfo import CountryInfo
count = input("Enter your country : ")
country = CountryInfo(count)
print("Capital is : ", country.capital())
print("Currencies is : ",country.currencies())
print("Language is : ",country.languages())
print("Borders are : ", country.borders())
print("Others names : ",country.alt_spellings())
# Out:
# Enter your country : Russia
# Capital is :  Moscow
# Currencies is :  ['RUB']
# Language is :  ['ru']
# Borders are :  ['AZE', 'BLR', 'CHN', 'EST', 'FIN', 'GEO', 'KAZ', 'PRK', 'LVA', 'LTU', 'MNG', 'NOR', 'POL', 'UKR']
# Others names :  ['RU', 'Rossiya', 'Russian Federation', 'Российская Федерация', 'Rossiyskaya Federatsiya']
