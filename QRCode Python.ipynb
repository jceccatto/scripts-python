# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.youtube.com/watch?v=oR1c_C1YgQ8

# %%
pip install pyqrcode
# Out:
# Collecting pyqrcode
#   Downloading PyQRCode-1.2.1.zip (41 kB)
#      -------------------------------------- 41.9/41.9 kB 511.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: pyqrcode
#   Running setup.py install for pyqrcode: started
#   Running setup.py install for pyqrcode: finished with status 'done'
# Successfully installed pyqrcode-1.2.1
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: pyqrcode is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
import pyqrcode
from PIL import Image
link = input("Enter anything to generate QR : ")
qr_code = pyqrcode.create(link)
qr_code.png("QRCode.png", scale = 5)
Image.open(QRCode.png)
# Out:
# Enter anything to generate QR : https://www.globo.com/
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 5
#       3 link = input("Enter anything to generate QR : ")
#       4 qr_code = pyqrcode.create(link)
# ----> 5 qr_code.png("QRCode.png", scale = 5)
#       6 Image.open(QRCode.png)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyqrcode\__init__.py:462, in QRCode.png(self, file, scale, module_color, background, quiet_zone)
#     416 def png(self, file, scale=1, module_color=(0, 0, 0, 255),
#     417         background=(255, 255, 255, 255), quiet_zone=4):
#     418     """This method writes the QR code out as an PNG image. The resulting
#     419     PNG has a bit depth of 1. The file parameter is used to specify where
#     420     to write the image to. It can either be an writable stream or a
#    (...)
#     460                      background=(0xff, 0xff, 0xff, 0x88)) #50% transparent white
#     461     """
# --> 462     builder._png(self.code, self.version, file, scale,
#     463                  module_color, background, quiet_zone)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyqrcode\builder.py:1266, in _png(code, version, file, scale, module_color, background, quiet_zone, debug)
#    1244 def _png(code, version, file, scale=1, module_color=(0, 0, 0, 255),
#    1245          background=(255, 255, 255, 255), quiet_zone=4, debug=False):
#    1246     """See: pyqrcode.QRCode.png()
#    1247
#    1248     This function was abstracted away from QRCode to allow for the output of
#    (...)
#    1264             modules) to the output (default: ``False``).
#    1265     """
# -> 1266     import png
#    1268     # Coerce scale parameter into an integer
#    1269     try:
#
# ModuleNotFoundError: No module named 'png'
